# %% [markdown]
# Autoría: Albert Ripoll
#
# Fuentes consultadas:
#
# * Clase de Danilo para parte del código para el bonus.
# * Google para las imágenes insertadas.

# %% [markdown]
# # Probability

# %% [markdown]
# ## Reto 1
# Hay una caja con 10 bolas blancas, 12 bolas rojas y 8 bolas negras. Calcula la probabilidad de:
# * Sacar una bola blanca.
# * Sacar una bola blanca en la primera extracción y una bola negra en la segunda extracción sin reemplazar la primera.
# * Sacar una bola blanca en la primera extracción y una bola negra en la segunda extracción reemplazando la primera.
# * Sacar 3 bolas y que sean todas de diferentes colores.

# %%
# Datos
blancas = 10
rojas = 12
negras = 8
total = blancas + rojas + negras

# FÓRMULAS DEDUCIDAS EN LOS VÍDEOS ADJUNTOS Y PDF

print(f"La probabilidad de sacar una bola blanca es P(B) = {blancas / total}")

print(f"La probabilidad de sacar una bola blanca en la primera extracción y una bola negra en la segunda extracción sin reemplazar es P(B_1 ∩ N_2) = {blancas/total * negras/(total-1)}")

print(f"La probabilidad de sacar una bola blanca en la primera extracción y una bola negra en la segunda extracción con reemplazo es P(B_1 ∩ N_2) = {blancas/total * negras/total}")

print(f"La probabilidad de sacar 3 bolas de distintos colores sin remplazo es = {6 * blancas/total * rojas/total * negras/total}")
print(f"La probabilidad de sacar 3 bolas de distintos colores con remplazo es = {6 * (blancas/total * rojas/(total-1) * negras/(total-2))}")
# Out:
# La probabilidad de sacar una bola blanca es P(B) = 0.3333333333333333
# La probabilidad de sacar una bola blanca en la primera extracción y una bola negra en la segunda extracción sin reemplazar es P(B_1 ∩ N_2) = 0.09195402298850575
# La probabilidad de sacar una bola blanca en la primera extracción y una bola negra en la segunda extracción con reemplazo es P(B_1 ∩ N_2) = 0.08888888888888888
# La probabilidad de sacar 3 bolas de distintos colores sin remplazo es = 0.21333333333333335
# La probabilidad de sacar 3 bolas de distintos colores con remplazo es = 0.23645320197044334

# %% [markdown]
# ## Reto 2
#
# Quieres ir de picnic el sábado. Odias la lluvia y quieres planificar tu fin de semana. Para ayudarte a tomar una decisión, recopilas los siguientes datos sobre los días lluviosos:
#
# * El 40% de todos los días están nublados.
# * Aproximadamente el 50% de los días nublados son lluviosos.
# * Aproximadamente el 20% de los días no nublados son lluviosos.
#
# ¿Cuál es la probabilidad de que llueva el próximo sábado?

# %%
# Datos
PNsi = 0.4 # P(Nublado_si)
PLsiNsi = 0.5 # P(Llueve_si | Nublado_si)
PLsiNno = 0.2 # P(Llueve_si | Nublado_no)

# FÓRMULAS DEDUCIDAS EN LOS VÍDEOS ADJUNTOS Y PDF

print(f"La probabilidad de que llueva el próximo sábado es P(L) = {PNsi * PLsiNsi + (1-PNsi) * PLsiNno}")
# Out:
# La probabilidad de que llueva el próximo sábado es P(L) = 0.32

# %% [markdown]
# ## Reto 3
#
# A y B son eventos de una probabilidad tal que \(P(A) = 0.3\), \(P(B) = 0.6\) y \(P(A ∩ B) = 0.1\)
#
# ¿Cuáles de las siguientes afirmaciones son verdaderas?
# **SUGERENCIA: dibuja un gran diagrama de Venn a tu lado**
# * \(P(¬{A}) = 0.7\)
# * \(P(A ∪ B) = 0.6\)
# * \(P(A ∩ ¬𝐵) = 0.2\)
# * \(P(A ∪ ¬{A}) = 1\)
# * \(P(A ∩ (B ∪ ¬{B})) = 0.4\)
# * \(P(¬{A} ∩ ¬{B}) = 0.3\)
# * \(P(¬{A ∩ B}) = 0.9\)

# %%
# Datos
PA = 0.3
PB = 0.6
PAinterB = 0.1

# RESPUESTAS EXPLICADAS EN PDF CON DIAGRAMA DE VENN O FÓRMULAS

print("Se calcula respuesta correcta con la fórmula a partir de los datos y ")
print(f"se imprime {True} si es igual que la del enunciado o {False} si es distinta al enunciado. \n")

print(f"P(¬A) = {1-PA} ", 1-PA==0.7)
print(f"P(A ∪ B) = {round(PA+PB-PAinterB,2)} ", round(PA+PB-PAinterB,2) == 0.6)
print(f"P(A ∩ ¬B) = {round(PA-PAinterB,2)} ", round(PA-PAinterB,2) == 0.2)
print(f"P(A ∪ ¬A) = {PA + (1-PA)} ", PA + (1-PA) == 1)
print(f"P(A ∩ (B ∪ ¬B)) = {PA * 1} ", PA * 1 == 0.4)
print(f"P(¬A ∩ ¬B) = {round(1 - (PA+PB-PAinterB),2)} ", round(1 - (PA+PB-PAinterB),2) == 0.3)
print(f"P(¬A∩B) = {1-PAinterB} ", 1-PAinterB == 0.9)
# Out:
# Se calcula respuesta correcta con la fórmula a partir de los datos y
# se imprime True si es igual que la del enunciado o False si es distinta al enunciado.
#
# P(¬A) = 0.7  True
# P(A ∪ B) = 0.8  False
# P(A ∩ ¬B) = 0.2  True
# P(A ∪ ¬A) = 1.0  True
# P(A ∩ (B ∪ ¬B)) = 0.3  False
# P(¬A ∩ ¬B) = 0.2  False
# P(¬A∩B) = 0.9  True

# %% [markdown]
# ## Reto 4
#
# * Si alguien viaja a China, la probabilidad de contraer Covid es del 1%
# * Si alguien viaja a Italia, la probabilidad de contraer Covid es del 20%
#
# Lanzo un dado con números 1, 2, 3, 4, 5, 6:
# * Si sale 1: Vuelo a Italia
# * Si no sale 1: Vuelo a China
#
# Durante mi viaje, contraje Covid. ¿Cuál es la probabilidad de que haya volado a China?

# %%
# Datos
PI=1/6 # P(I)
PC=1-PI # P(C)
PCsi=0.01 # P(C|sí covid)
PIsi=0.2 # P(I|sí covid)

# FÓRMULAS DEDUCIDA Y EXPLICADA EN PDF Y VÍDEO

print(f"La probabilidad de que haya volado a China sabiendo que contrajo covid es P(C|sí) = {PC * PCsi / (PC * PCsi + PI * PIsi)}")
# Out:
# La probabilidad de que haya volado a China sabiendo que contrajo covid es P(C|sí) = 0.2

# %% [markdown]
# ## BONUS
#
# Lanzas 2 dados. ¿Cuál es la probabilidad de que la suma de los números sea 7? ¿Y 8? ¿Y 9? Luego simula 10000 veces y dibuja un gráfico de conteo.
#
# Explicación:
#
# **Sigue una distribución triangular discreta**
#
# P(suma=2) = 1/36 → Un caso de 36 (solo el caso de que el primer dado es 1 y el segundo también)
#
# P(suma=3) = 2/36 → Dos casos de 36 (el primer dado puede ser 1 y el segundo 2 o el primer que sea 2 y el segundo 1)
#
# P(suma=4) = 3/36 → Tres casos de 36
#
# P(5) = 4/36  → Cuatro casos de 36
#
# P(6) = 5/36 → ...
#
# P(7) = 6/36
#
# P(8) = P(6) = 5/36
#
# P(9) = P(5) = 4/36
#
# P(10) = P(4) = 3/36
#
# P(11) = P(3) = 2/36
#
# P(12) = P(2) = 1/36
#
# En la siguiente imagen podemos ver los casos (posibles dados 1 y 2 que dan como resultado la suma indicada en el eje x. El número encima representa la probabilidad en tato por 1.
#
# ![image (1).png](data:image/png;base64,...)
#
# En la siguiente imagen vemos la combinación del dado 1 en fila y del dado 2 en columna y el resultado de su suma Vemos que hay 6·6=36 casos totales y que hay 1 caso con un 2, 2 casos con un 3, 3 casos con un 4...
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Simulado para dados de 6 caras

# %%
import random
num_lanzamientos = 10000
n = 6 # número de caras del dado

def lanzar_dado(n:int) -> int:
  """ Retorna el resultado de un dado de n caras.
  Entrada: n(int) = número de caras del dado
  Salida: (int) resultado del dado entre 1 y n"""
  return random.randint(1, n)

# Inicialización de posibles resultados de la suma de 2 dados de n caras.
suma_probabilidades = {resultado : 0 for resultado in range(2, 2*n+1)}
suma_frecuencias = {resultado : 0 for resultado in range(2, 2*n+1)}

# Para cada lanzamiento, se genera un número aleatorio para cada dado, se suma el resultado y se incrementa en 1 en el diccionario esa suma.
for _ in range(num_lanzamientos):
  dado1 = lanzar_dado(n)
  dado2 = lanzar_dado(n)
  suma_dados = dado1 + dado2
  suma_frecuencias[suma_dados] += 1

# Calculo de la probabilidad dividiendo la frecuencia de cada resultado por el número de lanzamientos total
for resultado in range(2, 2*n+1):
  suma_probabilidades[resultado] = suma_frecuencias[resultado] / num_lanzamientos

# Imprimir resultados
print("suma_frecuencias    ", suma_frecuencias)
print("suma_probabilidades ", suma_probabilidades)
# Out:
# suma_frecuencias     {2: 272, 3: 575, 4: 856, 5: 1140, 6: 1355, 7: 1666, 8: 1380, 9: 1067, 10: 829, 11: 575, 12: 285}
# suma_probabilidades  {2: 0.0272, 3: 0.0575, 4: 0.0856, 5: 0.114, 6: 0.1355, 7: 0.1666, 8: 0.138, 9: 0.1067, 10: 0.0829, 11: 0.0575, 12: 0.0285}

# %%
import matplotlib.pyplot as plt

plt.bar(suma_probabilidades.keys(), suma_probabilidades.values())
plt.show()

# %% [markdown]
# ## Teórico para dados de 6 caras

# %%
def crear_lista(n):
  """ Crea una lista de naturales ascendente de 1 hasta el valor n que desciende hasta el 1 nuevamente.
  Esto son las combinaciones posibles de dos dados de ir obteniendo un número de suma mayor, o sea la distribución triangular."""
  ascendente = list(range(1, n + 1))  # Lista ascendente: 1 a n
  descendente = list(range(n - 1, 0, -1))  # Lista descendente: n-1 a 1
  return ascendente + descendente  # Combinar ambas listas

""" Se representan las sumas posibles range(2, 2*n+1)
 en frente a la probabilidad teórica de dichas sumas
 Esa probabilidad se obtiene dividiendo las combinaciones de crear_lista con los casos posibles de n*n = n**2 resultados totales"""
plt.bar(list(range(2, 2*n+1)), [x / (n**2) for x in crear_lista(n)])
plt.xticks(range(2, 2*n + 1, 2))
plt.show()

# %% [markdown]
# ## Simulado para dados de distintas caras
#
# Simplemente modificamos el n=6 del primer código y podemos cambiar num_lanzamientos

# %%
import random
num_lanzamientos = 1000
n = 10 # número de caras del dado

def lanzar_dado(n:int) -> int:
  """ Retorna el resultado de un dado de n caras.
  Entrada: n(int) = número de caras del dado
  Salida: (int) resultado del dado entre 1 y n"""
  return random.randint(1, n)

# Inicialización de posibles resultados de la suma de 2 dados de n caras.
suma_probabilidades = {resultado : 0 for resultado in range(2, 2*n+1)}
suma_frecuencias = {resultado : 0 for resultado in range(2, 2*n+1)}

# Para cada lanzamiento, se genera un número aleatorio para cada dado, se suma el resultado y se incrementa en 1 en el diccionario esa suma.
for _ in range(num_lanzamientos):
  dado1 = lanzar_dado(n)
  dado2 = lanzar_dado(n)
  suma_dados = dado1 + dado2
  suma_frecuencias[suma_dados] += 1

# Calculo de la probabilidad dividiendo la frecuencia de cada resultado por el número de lanzamientos total
for resultado in range(2, 2*n+1):
  suma_probabilidades[resultado] = suma_frecuencias[resultado] / num_lanzamientos

# Imprimir resultados
print("suma_frecuencias    ", suma_frecuencias)
print("suma_probabilidades ", suma_probabilidades)
# Out:
# suma_frecuencias     {2: 7, 3: 10, 4: 24, 5: 40, 6: 41, 7: 63, 8: 71, 9: 88, 10: 70, 11: 119, 12: 101, 13: 85, 14: 63, 15: 59, 16: 49, 17: 44, 18: 32, 19: 24, 20: 10}
# suma_probabilidades  {2: 0.007, 3: 0.01, 4: 0.024, 5: 0.04, 6: 0.041, 7: 0.063, 8: 0.071, 9: 0.088, 10: 0.07, 11: 0.119, 12: 0.101, 13: 0.085, 14: 0.063, 15: 0.059, 16: 0.049, 17: 0.044, 18: 0.032, 19: 0.024, 20: 0.01}

# %%
import matplotlib.pyplot as plt

plt.bar(suma_probabilidades.keys(), suma_probabilidades.values())
plt.xticks(range(2, 2*n + 1, 2))
plt.show()

# %% [markdown]
# ## Teórico para dados de distintas caras

# %%
plt.bar(list(range(2, 2*n+1)), [x / (n**2) for x in crear_lista(n)])
plt.xticks(range(2, 2*n + 1, 2))
plt.show()
